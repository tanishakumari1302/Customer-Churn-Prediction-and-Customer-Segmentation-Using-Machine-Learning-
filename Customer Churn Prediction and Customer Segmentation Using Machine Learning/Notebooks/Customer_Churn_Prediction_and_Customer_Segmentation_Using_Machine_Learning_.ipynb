# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
"Telco_customer_churn.xlsx"
# Out:
# 'Telco_customer_churn.xlsx'

# %%
df=pd.read_excel("Telco_customer_churn.xlsx")

# %%
print("Dataset Shape:", df.shape)

print("\nNumber of Rows:", df.shape[0])

print("Number of Columns:", df.shape[1])
# Out:
# Dataset Shape: (7043, 33)
#
# Number of Rows: 7043
# Number of Columns: 33

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
# ...

# %%
df = pd.read_excel("Telco_customer_churn.xlsx")
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
#churn label yes or no but computer cant read string(semantically) so we must map this
#churn means customers leaving yes->leaving, no->not leaving
#do mapping(2 values)
#yes -> 1.....customer leaving
#no -> 0.....customer not leaving

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
print("Data Types:\n")
print(df.dtypes)
# Out:
# Data Types:
#
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# ...

# %%
print("\nMissing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
df['Churn Label'].value_counts().plot(kind='bar')
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()

# %%
churn_percent = df['Churn Label'].value_counts(normalize=True)*100
print(churn_percent)
# Out:
# Churn Label
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.histplot(df['Tenure Months'], bins = 30, kde = True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('Distribution of Tenure v/s No of Customers')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x='Tenure Months',
    hue='Churn Label',
    bins=30,
    kde=True
)

plt.title('Tenure Distribution by Churn')
plt.show()

# %%
tenure_churn = df.groupby('Churn Label')['Tenure Months'].mean()

print(tenure_churn)
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df['Tenure Months'].min()
# Out:
# 0

# %%
df['Tenure Months'].max()
# Out:
# 72

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.boxplot( x = 'Churn Label', y = 'Tenure Months', data = df, color='yellow')
plt.xlabel('Churn Label')
plt.ylabel('Tenure Months')
plt.title('Distribution of Churn v/s Tenure Months')
plt.show()

# %%
#25 percentile is the first line, 50 is second, 75 is third in the box
#50 percent of customers leave the service in first 10months
#50 percent of customers avail the service  in 38 months

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df[df['Churn Label'] == 'Yes']
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 1864  1699-HPSBG      1  United States  California  Palm Springs     92264
# 1865  8775-CEBBJ      1  United States  California        Seeley     92273
# 1866  6894-LFHLY      1  United States  California         Vidal     92280
# 1867  0639-TSIQW      1  United States  California   White Water     92282
# 1868  8361-LTMKD      1  United States  California  Apple Valley     92307
#
# ...

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
print("Minimum Tenure:", df['Tenure Months'].min())

print("Maximum Tenure:", df['Tenure Months'].max())

print("Average Tenure:", df['Tenure Months'].mean())

print("Median Tenure:", df['Tenure Months'].median())
# Out:
# Minimum Tenure: 0
# Maximum Tenure: 72
# Average Tenure: 32.37114865824223
# Median Tenure: 29.0

# %%
df['Tenure Months'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: Tenure Months, dtype: float64

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.boxplot( x = 'Churn Label', y = 'Monthly Charges', data = df, color='yellow')
plt.xlabel('Churn Label')
plt.ylabel('Months Charges')
plt.title('Distribution of Churn v/s Months Charges')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    x='Churn Label',
    y='Monthly Charges',
    data=df
)

plt.title('Monthly Charges Distribution by Churn')
plt.show()

# %%
print(df.groupby('Churn Label')['Monthly Charges'].mean())
# Out:
# Churn Label
# No     61.265124
# Yes    74.441332
# Name: Monthly Charges, dtype: float64

# %%
print(df.groupby('Churn Label')['Monthly Charges'].describe())
# Out:
#               count       mean        std    min    25%     50%   75%     max
# Churn Label
# No           5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# Yes          1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %%
df[df['Churn Label'] == 'Yes']['Monthly Charges'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
print("Churned Customers")
print(
    df[df['Churn Label']=='Yes']['Monthly Charges']
    .quantile([0.25,0.5,0.75])
)

print("\nRetained Customers")
print(
    df[df['Churn Label']=='No']['Monthly Charges']
    .quantile([0.25,0.5,0.75])
)
# Out:
# Churned Customers
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64
#
# Retained Customers
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df.groupby('Churn Label')['Monthly Charges'].describe()
# Out:
#               count       mean        std    min    25%     50%   75%     max
# Churn Label
# No           5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# Yes          1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %%
print("Churned Customers")
print(df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75]))

print("\nRetained Customers")
print(df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75]))
# Out:
# Churned Customers
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64
#
# Retained Customers
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label'] == 'No']['Monthly Charges'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
comparison = pd.DataFrame({
    'Churned': df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75]),
    'Retained': df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75])
})

comparison
# Out:
#       Churned  Retained
# 0.25    56.15    25.100
# 0.50    79.65    64.425
# 0.75    94.20    88.400

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.countplot( x = 'Contract', hue = 'Churn Label', data = df)
plt.xlabel('Contract')
plt.ylabel('Count')
plt.title('Contract v/s Count')
plt.show()

# %%
pd.crosstab(
    df['Contract'],
    df['Churn Label'],
    normalize='index'
)*100
# Out:
# Churn Label            No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
contract_churn = pd.crosstab(
    df['Contract'],
    df['Churn Label'],
    normalize='index'
)*100

contract_churn.plot(
    kind='bar',
    stacked=True,
    figsize=(8,5)
)

plt.title('Contract-wise Churn Percentage')
plt.ylabel('Percentage')
plt.show()

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'], bins=30, kde=True)

plt.title("Distribution of Monthly Charges")
plt.show()

# %%
print("Average Monthly Charge:", df['Monthly Charges'].mean())

print("Median Monthly Charge:", df['Monthly Charges'].median())
# Out:
# Average Monthly Charge: 64.76169246059918
# Median Monthly Charge: 70.35

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
print(df['Contract'].value_counts())
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
(df['Contract'].value_counts(normalize=True)*100)
# Out:
# Contract
# Month-to-month    55.019168
# Two year          24.066449
# One year          20.914383
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (8, 5) )
sns.countplot(x='Contract', data=df)
plt.xlabel('Contract')
plt.ylabel('Count')
plt.title('Contract v/s Count')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Churn Label', y='Tenure Months', data=df)

plt.xlabel('churn label')

plt.ylabel('tenure month')

plt.title('churn vs tenure motn')

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x='Churn Label', y='Tenure Months', data=df)
sns.stripplot(
    x='Churn Label',
    y='Tenure Months',
    data=df,
    color='black',
    alpha=0.3
)

plt.xlabel('Churn Label')
plt.ylabel('Tenure (Months)')
plt.title('Churn vs Tenure Months')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Churn Label', y='Monthly Charges', data=df)

plt.xlabel('churn label')

plt.ylabel('month charges')

plt.title('churn vs month charges')

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x='Churn Label', y='Monthly Charges', data=df)
sns.stripplot(
    x='Churn Label',
    y='Monthly Charges',
    data=df,
    color='black',
    alpha=0.3
)

plt.xlabel('Churn Label')
plt.ylabel('Monthly Charges')
plt.title('Churn vs Monthly Charges')

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Churn Label', y='Monthly Charges', data=df)

plt.xlabel('churn label')

plt.ylabel('month charges')

plt.title('churn vs month charges')

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Churn Label',
    y='Monthly Charges',
    data=df,
    palette='Set2'
)

plt.xlabel('Churn Label')
plt.ylabel('Monthly Charges')
plt.title('Churn vs Monthly Charges')

plt.show()

# %%
import pandas as pd
df=pd.read_excel("Telco_customer_churn.xlsx")
contract_churn=pd.crosstab(df['Churn Label'], df['Contract'])

# %%
contract_churn_percent = pd.crosstab(
    df['Contract'],
    df['Churn Label'],
    normalize='index'
) * 100

contract_churn_percent
# Out:
# Churn Label            No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
contract_churn_percent.plot(
    kind='bar',
    stacked=True,
    figsize=(8,5)
)

plt.title("Contract-wise Churn Percentage")
plt.ylabel("Percentage")
plt.show()

# %%
 plt.figure(figsize=(8,5))
 sns.boxplot(x='Churn Label', y='Tenure Months', data=df)
 plt.xlabel('Churn Label')
 plt.ylabel('Tenure Months')
 plt.title('Churn Label vs Tenure Month')
 plt.show()

print(df['Churn Label']=="Yes")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: Churn Label, Length: 7043, dtype: bool

# %%
print(
    df.groupby('Churn Label')['Tenure Months'].mean()
)
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
print(
    df.groupby('Churn Label')['Tenure Months'].median()
)
# Out:
# Churn Label
# No     38.0
# Yes    10.0
# Name: Tenure Months, dtype: float64

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
contract_percent = df['Contract'].value_counts(normalize=True) * 100
print(contract_percent)
# Out:
# Contract
# Month-to-month    55.019168
# Two year          24.066449
# One year          20.914383
# Name: proportion, dtype: float64

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['Internet Service'].value_counts()
# Out:
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
(df['Internet Service'].value_counts(normalize=True)*100)
# Out:
# Internet Service
# Fiber optic    43.958540
# DSL            34.374556
# No             21.666903
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='Internet Service',
    data=df
)

plt.title("Internet Service Distribution")
plt.show()

# %%
plt.figure(figsize = (8, 5) )
sns.countplot(x='Internet Service', hue='Churn Label',data=df)
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.title('Internet Service v/s count')
plt.show()

# %%
internet_churn = pd.crosstab(
    df['Internet Service'],
    df['Churn Label'],
    normalize='index'
)*100

plt.figure(figsize=(8,5))

sns.heatmap(
    internet_churn,
    annot=True,
    fmt='.1f',
    cmap='YlGnBu'
)

plt.title("Internet Service vs Churn Percentage")
plt.show()

# %%
internet_churn.plot(
    kind='bar',
    stacked=True,
    figsize=(8,5)
)

plt.ylabel('Percentage')
plt.title('Internet Service-wise Churn Percentage')
plt.show()

# %%
plt.figure(figsize = (8, 5) )
sns.countplot(x='Payment Method', hue='Churn Label', data=df)
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Payment Method v/s count')
plt.show()

# %%
payment_churn = pd.crosstab(
    df['Payment Method'],
    df['Churn Label'],
    normalize='index'
) * 100

payment_churn
# Out:
# Churn Label                       No        Yes
# Payment Method
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    payment_churn,
    annot=True,
    fmt='.1f',
    cmap='YlGnBu'
)

plt.title("Payment Method vs Churn Percentage")
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
(df['Payment Method'].value_counts(normalize=True)*100)
# Out:
# Payment Method
# Electronic check             33.579441
# Mailed check                 22.887974
# Bank transfer (automatic)    21.922476
# Credit card (automatic)      21.610109
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='Payment Method',
    data=df
)

plt.xticks(rotation=20)
plt.title("Payment Method Distribution")
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['Tech Support'].value_counts()
# Out:
# Tech Support
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
df['Tech Support'].value_counts(normalize=True)*100
# Out:
# Tech Support
# No                     49.311373
# Yes                    29.021724
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
tech_churn = pd.crosstab(
    df['Tech Support'],
    df['Churn Label'],
    normalize='index'
)*100

tech_churn
# Out:
# Churn Label                 No        Yes
# Tech Support
# No                   58.364526  41.635474
# No internet service  92.595020   7.404980
# Yes                  84.833659  15.166341

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    tech_churn,
    annot=True,
    fmt='.1f',
    cmap='YlGnBu'
)

plt.title("Tech Support vs Churn Percentage")
plt.show()

# %%
plt.figure(figsize = (8, 5) )
sns.countplot(x='Tech Support', hue='Churn Label', data=df)
plt.xlabel('Tech Support')
plt.ylabel('Count')
plt.title('Tech Support v/s count')
plt.show()

# %%
tech_churn = pd.crosstab(
    df['Tech Support'],
    df['Churn Label'],
    normalize='index'
) * 100

print(tech_churn)
# Out:
# Churn Label                 No        Yes
# Tech Support
# No                   58.364526  41.635474
# No internet service  92.595020   7.404980
# Yes                  84.833659  15.166341

# %%
avg_tenure=df.groupby("Churn Label")["Tenure Months"].mean()

# %%
print(df.groupby("Churn Label")["Tenure Months"].median())
# Out:
# Churn Label
# No     38.0
# Yes    10.0
# Name: Tenure Months, dtype: float64

# %%
avg_tenure.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title("Average Tenure by Churn Status")
plt.ylabel("Average Tenure (Months)")
plt.show()

# %%
df.groupby("Churn Label")["Tenure Months"].agg(
    ['count','mean','median','min','max']
)
# Out:
#              count       mean  median  min  max
# Churn Label
# No            5174  37.569965    38.0    0   72
# Yes           1869  17.979133    10.0    1   72

# %%
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
from scipy.stats import ttest_ind

churn_yes = df[df['Churn Label']=='Yes']['Monthly Charges']
churn_no = df[df['Churn Label']=='No']['Monthly Charges']

t_stat, p_value = ttest_ind(churn_yes, churn_no)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 16.536738015936308
# P-value: 2.7066456068884154e-60

# %%
if p_value < 0.05:
    print("Reject Null Hypothesis")
    print("Monthly Charges significantly affect churn")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Reject Null Hypothesis
# Monthly Charges significantly affect churn

# %%
from scipy.stats import ttest_ind

churn_yes = df[df['Churn Label']=='Yes']['Tenure Months']
churn_no = df[df['Churn Label']=='No']['Tenure Months']

t_stat, p_value = ttest_ind(churn_yes, churn_no)

print("P-value:", p_value)
# Out:
# P-value: 7.99905796059022e-205

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(
    df['Contract'],
    df['Churn Label']
)

chi2, p, dof, expected = chi2_contingency(
    contingency_table
)

print("P-value:", p)
# Out:
# P-value: 5.863038300673391e-258

# %%
numerical_cols=['Tenure Months','Monthly Charges','Churn Value','Churn Score','CLTV']
correlation_matrix = df[numerical_cols].corr()
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
if p < 0.05:
    print("Contract Type and Churn are related")
else:
    print("No significant relationship")
# Out:
# Contract Type and Churn are related

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title("Correlation Matrix")
plt.show()

# %%
contract_churn=pd.crosstab(df['Contract'], df['Churn Label'])

# %%
contract_churn=pd.crosstab(df['Contract'], df['Churn Label'],normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df.shape
# Out:
# (7043, 33)

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
import pandas as pd
df = pd.read_excel("Telco_customer_churn.xlsx")
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# 2234    0
# 2438    0
# 2568    0
# 2667    0
# 2856    0
# 4331    0
# 4687    0
# 5104    0
# 5719    0
# 6772    0
# 6840    0
# Name: Tenure Months, dtype: int64

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# (11,)

# %%
df['Total Charges']=df['Total Charges'].fillna(0)

# %%
import pandas as pd
df = pd.read_excel("Telco_customer_churn.xlsx")
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')
df['Total Charges']=df['Total Charges'].fillna(0)
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
drop_columns=['CustomerID','Count','Country','State','Zip Code','Lat Long','Latitude','Longitude','Churn Label','Churn Score','CLTV','Churn Reason']

# %%
df=df.drop(columns=drop_columns)

# %%
df.shape
# Out:
# (7043, 21)

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded.head()
# Out:
#    Tenure Months  Monthly Charges  Total Charges  Churn Value  City_Acton  \
# 0              2            53.85         108.15            1       False
# 1              2            70.70         151.65            1       False
# 2              8            99.65         820.50            1       False
# 3             28           104.80        3046.05            1       False
# 4             49           103.70        5036.30            1       False
#
#    City_Adelanto  City_Adin  City_Agoura Hills  City_Aguanga  City_Ahwahnee  \
# 0          False      False              False         False          False
# 1          False      False              False         False          False
# 2          False      False              False         False          False
# 3          False      False              False         False          False
# 4          False      False              False         False          False
#
# ...

# %%
df_encoded.shape
# Out:
# (7043, 1159)

# %%
df=df.drop(columns=['City'])

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %%
print(df['Churn Value'].value_counts())

print(
    df['Churn Value'].value_counts(normalize=True)*100
)
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64
# Churn Value
# 0    73.463013
# 1    26.536987
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(15,10))

sns.heatmap(
    df_encoded.corr(),
    cmap='coolwarm',
    center=0
)

plt.title("Encoded Feature Correlation")
plt.show()

# %%
corr = df_encoded.corr()['Churn Value']

print(
    corr.sort_values(
        ascending=False
    ).head(10)
)
# Out:
# Churn Value                        1.000000
# Internet Service_Fiber optic       0.308020
# Payment Method_Electronic check    0.301919
# Monthly Charges                    0.193356
# Paperless Billing_Yes              0.191825
# Senior Citizen_Yes                 0.150889
# Streaming TV_Yes                   0.063228
# Streaming Movies_Yes               0.061382
# Multiple Lines_Yes                 0.040102
# City_Wrightwood                    0.039663
# Name: Churn Value, dtype: float64

# %%
print(df_encoded.isnull().sum().sum())
# Out:
# 0

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
# ...

# %%
X=df_encoded.drop('Churn Value',axis=1)
Y=df_encoded['Churn Value']

# %%
X
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %%
X.shape
Y.shape
# Out:
# (7043,)

# %%
print(X)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# ...

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %%
print(Y.value_counts())

print(Y.value_counts(normalize=True)*100)
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64
# Churn Value
# 0    73.463013
# 1    26.536987
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (5634, 30)
# (1409, 30)

# %%
print("Number of Features:", X.shape[1])
# Out:
# Number of Features: 30

# %%
X = df_encoded.drop('Churn Value', axis=1)
Y = df_encoded['Churn Value']

print("X Shape:", X.shape)
print("Y Shape:", Y.shape)

print(Y.value_counts())
# Out:
# X Shape: (7043, 30)
# Y Shape: (7043,)
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Machine Learning implementations**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (5634, 30)

# %%
X_test.shape
# Out:
# (1409, 30)

# %%
Y_train.shape
# Out:
# (5634,)

# %%
Y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf_model.fit(X_train, Y_train)
y_pred = rf_model.predict(X_test)
print("Model fitted and predictions generated.")
# Out:
# Model fitted and predictions generated.

# %%
rf = RandomForestClassifier(...)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(Y_test, y_pred))

print(classification_report(Y_test, y_pred))
# Out:
# [[902 107]
#  [195 205]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    Y_test,
    y_pred
)

print(cm)
# Out:
# [[902 107]
#  [195 205]]

# %%
plt.figure(figsize=(6,4))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        Y_test,
        Y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print(importance.head(10))
# Out:
#                             Feature  Importance
# 2                     Total Charges    0.190197
# 0                     Tenure Months    0.173457
# 1                   Monthly Charges    0.167753
# 28  Payment Method_Electronic check    0.038823
# 6                    Dependents_Yes    0.035459
# 10     Internet Service_Fiber optic    0.034156
# 25                Contract_Two year    0.029158
# 3                       Gender_Male    0.027464
# 5                       Partner_Yes    0.025513
# 26            Paperless Billing_Yes    0.025163

# %%
Y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, Y_pred)

print(cm)
# Out:
# [[902 107]
#  [195 205]]

# %%
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
Y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.7856635911994322

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(Y_test,y_pred)

# %%
print(cm)
# Out:
# [[902 107]
#  [195 205]]

# %%
from sklearn.metrics import classification_report

# %%
print (classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# Approach 1 -Handle class imbalance

# %%
rf_balanced=RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')
rf_balanced.fit(X_train,Y_train)
y_pred_balanced=rf_balanced.predict(X_test)
accuracy_balanced=accuracy_score(Y_test, y_pred_balanced)
cm_balanced=confusion_matrix(Y_test, y_pred_balanced)
print (accuracy_balanced,cm_balanced)
print (classification_report(Y_test, y_pred_balanced))
# Out:
# 0.7920511000709723 [[907 102]
#  [191 209]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1009
#            1       0.67      0.52      0.59       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_balanced.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importance.head(10))
# Out:
#                             Feature  Importance
# 2                     Total Charges    0.175032
# 0                     Tenure Months    0.169992
# 1                   Monthly Charges    0.147834
# 25                Contract_Two year    0.057075
# 6                    Dependents_Yes    0.047733
# 10     Internet Service_Fiber optic    0.038085
# 28  Payment Method_Electronic check    0.037015
# 13              Online Security_Yes    0.025335
# 24                Contract_One year    0.025143
# 3                       Gender_Male    0.024239

# %%
plt.figure(figsize=(6,4))

sns.heatmap(
    cm_balanced,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title('Balanced Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()

# %% [markdown]
# Approach 2 hyperparameter tuning

# %%
rf_tuned=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_tuned.fit(X_train,Y_train)
y_pred_tuned=rf_tuned.predict(X_test)

print (classification_report(Y_test, y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.59      0.75      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %%
from sklearn.metrics import accuracy_score

print(
    "Balanced RF Accuracy:",
    accuracy_score(Y_test, y_pred_balanced)
)

print(
    "Tuned RF Accuracy:",
    accuracy_score(Y_test, y_pred_tuned)
)
# Out:
# Balanced RF Accuracy: 0.7920511000709723
# Tuned RF Accuracy: 0.7828246983676366

# %%
top10 = feature_importance.head(10)

plt.figure(figsize=(8,5))

sns.barplot(
    x='Importance',
    y='Feature',
    data=top10
)

plt.title('Top 10 Important Features')
plt.show()

# %% [markdown]
# Apporoach 3 Feature importance analysis

# %%
import pandas as pd
feature_importance =pd.DataFrame({
    'feature':X.columns,
    'importance':rf_tuned.feature_importances_
})
feature_importance = feature_importance.sort_values(by='importance',ascending=False)
print (feature_importance)
# Out:
#                                    feature  importance
# 0                            Tenure Months    0.179069
# 2                            Total Charges    0.136460
# 25                       Contract_Two year    0.102861
# 1                          Monthly Charges    0.093681
# 6                           Dependents_Yes    0.068517
# 10            Internet Service_Fiber optic    0.060228
# 28         Payment Method_Electronic check    0.046732
# 24                       Contract_One year    0.036682
# 13                     Online Security_Yes    0.029356
# 19                        Tech Support_Yes    0.021106
# 26                   Paperless Billing_Yes    0.018064
# 5                              Partner_Yes    0.015846
# 12     Online Security_No internet service    0.014973
# 18        Tech Support_No internet service    0.014799
# 22    Streaming Movies_No internet service    0.014360
# 16   Device Protection_No internet service    0.012985
# ...

# %%
print(feature_importance.head(10))
# Out:
#                             feature  importance
# 0                     Tenure Months    0.179069
# 2                     Total Charges    0.136460
# 25                Contract_Two year    0.102861
# 1                   Monthly Charges    0.093681
# 6                    Dependents_Yes    0.068517
# 10     Internet Service_Fiber optic    0.060228
# 28  Payment Method_Electronic check    0.046732
# 24                Contract_One year    0.036682
# 13              Online Security_Yes    0.029356
# 19                 Tech Support_Yes    0.021106

# %%
print(feature_importance .tail(15))
# Out:
#                                    feature  importance
# 16   Device Protection_No internet service    0.012985
# 11                     Internet Service_No    0.012673
# 3                              Gender_Male    0.012586
# 15                       Online Backup_Yes    0.012213
# 9                       Multiple Lines_Yes    0.011690
# 14       Online Backup_No internet service    0.010298
# 4                       Senior Citizen_Yes    0.010257
# 20        Streaming TV_No internet service    0.010186
# 23                    Streaming Movies_Yes    0.010161
# 27  Payment Method_Credit card (automatic)    0.009430
# 21                        Streaming TV_Yes    0.009289
# 17                   Device Protection_Yes    0.009101
# 29             Payment Method_Mailed check    0.008800
# 7                        Phone Service_Yes    0.003872
# 8          Multiple Lines_No phone service    0.003725

# %%
X_selected=X.drop(['Phone Service_Yes','Multiple Lines_No phone service'],axis=1)

# %%
X_train_sel, X_test_sel, Y_train_sel, Y_test_sel = train_test_split(
    X_selected, Y, test_size=0.2, random_state=42)

# %%
rf_selected=RandomForestClassifier(n_estimators=300, max_depth=10, random_state=42, class_weight='balanced')
rf_selected.fit(X_train_sel,Y_train_sel)
y_pred_selected=rf_selected.predict(X_test_sel)

print (classification_report(Y_test, y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.60      0.74      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %% [markdown]
# approach ocombination of trees and depth

# %%
n_estimators_list=[100,200,300,400,500]
max_depth_list=[5,10,15,20]
results=[]
for n_trees in n_estimators_list:
  for depth in max_depth_list:
    rf=RandomForestClassifier(n_estimators=n_trees,max_depth=depth,random_state=42,class_weight='balanced')
    rf.fit(X_train,Y_train)
    y_pred=rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
n_estimators_list=[100,200,300,400,500]
max_depth_list=[5,10,15,20]
results=[]
for n_trees in n_estimators_list:
 for depth in max_depth_list:
  rf=RandomForestClassifier(n_estimators= n_trees,max_depth=depth,random_state=42,class_weight='balanced')
  rf.fit(X_train,Y_train)
  y_pred=rf.predict(X_test)
  accuracy=accuracy_score(Y_test,y_pred)
  recall=recall_score(Y_test,y_pred)
  precision=precision_score(Y_test,y_pred)
  f1=f1_score(Y_test,y_pred)
  results.append ({'Trees': n_trees, 'Depth':depth,'Accuracy':accuracy, 'Recall':recall, 'precision': precision, 'F1 Score':f1})
result_df=pd.DataFrame (results)
result_df=result_df.sort_values(by=['Recall','Accuracy'], ascending=False)
print(result_df.head(20))
# Out:
#     Trees  Depth  Accuracy  Recall  precision  F1 Score
# 0     100      5  0.745919  0.8200   0.534202  0.646943
# 8     300      5  0.743790  0.8200   0.531605  0.645034
# 12    400      5  0.743790  0.8125   0.531915  0.642928
# 4     200      5  0.742370  0.8100   0.530278  0.640950
# 16    500      5  0.740951  0.8050   0.528736  0.638256
# 1     100     10  0.775727  0.7525   0.581081  0.655773
# 9     300     10  0.782825  0.7475   0.593254  0.661504
# 13    400     10  0.782825  0.7475   0.593254  0.661504
# 17    500     10  0.781405  0.7475   0.590909  0.660044
# 5     200     10  0.782115  0.7450   0.592445  0.660022
# 10    300     15  0.806246  0.6400   0.664935  0.652229
# 14    400     15  0.803407  0.6375   0.658915  0.648030
# 18    500     15  0.801987  0.6375   0.655527  0.646388
# 6     200     15  0.804826  0.6350   0.663185  0.648787
# 2     100     15  0.802697  0.6300   0.659686  0.644501
# 3     100     20  0.787793  0.5325   0.655385  0.587586
# ...

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    data=result_df,
    x='Trees',
    y='Recall',
    hue='Depth',
    marker='o'
)

plt.title('Recall vs Number of Trees')
plt.show()

# %%
result_df.to_csv(
    "rf_hyperparameter_results.csv",
    index=False
)

# %%
from sklearn.model_selection import cross_val_score
final_rf=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')

# %%
cv_accuracy=cross_val_score(final_rf,X,Y,cv=5,scoring='accuracy')

# %%
cv_accuracy
# Out:
# array([0.76721079, 0.79772889, 0.76224273, 0.78551136, 0.78409091])

# %%
cv_accuracy.mean()
# Out:
# np.float64(0.7793569343183432)

# %%
cv_recall=cross_val_score(final_rf,X,Y,cv=5,scoring='recall')

# %%
cv_recall
# Out:
# array([0.70855615, 0.76470588, 0.74064171, 0.74331551, 0.71045576])

# %%
cv_recall.mean()
# Out:
# np.float64(0.7335350030823931)

# %% [markdown]
# **OPTIONAL **

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
import matplotlib.pyplot as plt

# %%
y_prob=rf_tuned.predict_proba(X)

# %%
y_prob=rf_tuned.predict_proba(X_test)

# %%
churn_probability= y_prob[:,1]

# %%
churn_prob=y_prob[:,1]

# %%
y_prob_test = rf_tuned.predict_proba(X_test)
churn_prob = y_prob_test[:, 1]

fpr,tpr,thresholds=roc_curve(Y_test,churn_prob)
auc_score= roc_auc_score(Y_test,churn_prob)
print(auc_score)
# Out:
# 0.857104806739346

# %%
churn_prob=y_prob[:,1]
fpr,tpr,thresholds=roc_curve(Y_test,churn_prob)
accuracy_score= roc_auc_score(Y_test,churn_prob)
print(accuracy_score)
# Out:
# 0.857104806739346

# %% [markdown]
# CUSTOMER SEGMENTATATION

# %%
segmentation_data=pd.DataFrame({
'Tenure Months':X_test['Tenure Months'],
 'Monthly Charges':X_test['Monthly Charges'],
 'Total Charges':X_test['Total Charges'],
 'Churn Probability':churn_probability})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 185              15            85.90        1269.55           0.716452
# 2715             18            56.80        1074.65           0.328659
# 3825              2            20.00          40.90           0.227716
# 1807              6            84.20         519.15           0.824308
# 132              40           104.80        4131.95           0.484764
# ...             ...              ...            ...                ...
# 6366             66           104.90        6891.45           0.120654
# 315              19            86.00        1532.45           0.711268
# 2439              2            90.35         190.50           0.709340
# 5002             68           110.20        7467.50           0.066674
# 1161             30            99.70        2967.35           0.779169
#
# [1409 rows x 4 columns]

# %%
high_risk = segmentation_data[
    segmentation_data['Churn Probability'] > 0.7
]

print(high_risk.head())
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 185              15            85.90        1269.55           0.716452
# 1807              6            84.20         519.15           0.824308
# 1263              8           105.50         829.55           0.896350
# 3732              2            91.45         171.45           0.901554
# 811               1            25.10          25.10           0.813903

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Re-initialize segmentation_data to ensure it has the base columns and no leftover cluster columns from previous runs
segmentation_data = pd.DataFrame({
    'Tenure Months':X_test['Tenure Months'],
    'Monthly Charges':X_test['Monthly Charges'],
    'Total Charges':X_test['Total Charges'],
    'Churn Probability':churn_probability
})

# Scale the numerical features for clustering
scaler = StandardScaler()
scaled_data = scaler.fit_transform(segmentation_data[['Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Probability']])

# Perform K-Means clustering with 3 clusters (as defined in `clusters_summary`)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(scaled_data)

# Add the cluster assignments to the segmentation_data DataFrame
segmentation_data['cluster'] = clusters

# Define cluster summaries and map them to create the 'cluster segment' column
clusters_summary = {
    0:'Budget Loyal Customer',
    1:'High Risk New Customer',
    2:'Loyal premium Customer'
}
segmentation_data['cluster segment'] = segmentation_data['cluster'].map(clusters_summary)

plt.figure(figsize=(8,5))

sns.countplot(
    x='cluster segment',
    data=segmentation_data,
    palette='viridis'
)

plt.title('Customer Risk Segmentation')
plt.xlabel('Customer Segment')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **implementattion of kmeans**

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

# %%
scaled_data = scaler.fit_transform(segmentation_data[['Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Probability']])
print(scaled_data[:5])
# Out:
# [[-0.69631406  0.6691038  -0.45048988  1.14226737]
#  [-0.57429095 -0.31419848 -0.53600108 -0.14949408]
#  [-1.22508089 -1.55768728 -0.98955267 -0.48574109]
#  [-1.0623834   0.61166002 -0.77972336  1.50154256]
#  [ 0.32054522  1.30774342  0.80537089  0.37050095]]

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,16):
   kmeans=KMeans(n_clusters=k, random_state=42)
   kmeans.fit(scaled_data)
   wcss.append(kmeans.inertia_)
plt.figure(figsize=(8,6))
plt.plot(range(1,16),wcss,marker='o')
plt.xlabel("Number of clusters k")
plt.ylabel('WCSS')
plt.show()

# %%
for k in range(1,16):
    pass

# %%
k = 4

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42
)

clusters = kmeans.fit_predict(
    scaled_data
)

segmentation_data['Cluster'] = clusters

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='Cluster',
    data=segmentation_data
)

plt.title('Customer Segments')
plt.show()

# %%
kmeans=KMeans(n_clusters=3,random_state=42)

# %%
clusters=kmeans.fit_predict(scaled_data)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 185              15            85.90        1269.55           0.716452
# 2715             18            56.80        1074.65           0.328659
# 3825              2            20.00          40.90           0.227716
# 1807              6            84.20         519.15           0.824308
# 132              40           104.80        4131.95           0.484764
# ...             ...              ...            ...                ...
# 6366             66           104.90        6891.45           0.120654
# 315              19            86.00        1532.45           0.711268
# 2439              2            90.35         190.50           0.709340
# 5002             68           110.20        7467.50           0.066674
# 1161             30            99.70        2967.35           0.779169
#
#       cluster         cluster segment  Cluster
# 185         0   Budget Loyal Customer        0
# ...

# %%
segmentation_data['cluster']= clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 185              15            85.90        1269.55           0.716452
# 2715             18            56.80        1074.65           0.328659
# 3825              2            20.00          40.90           0.227716
# 1807              6            84.20         519.15           0.824308
# 132              40           104.80        4131.95           0.484764
# ...             ...              ...            ...                ...
# 6366             66           104.90        6891.45           0.120654
# 315              19            86.00        1532.45           0.711268
# 2439              2            90.35         190.50           0.709340
# 5002             68           110.20        7467.50           0.066674
# 1161             30            99.70        2967.35           0.779169
#
#       cluster         cluster segment  Cluster
# 185         0   Budget Loyal Customer        0
# ...

# %%
clusters_summary = segmentation_data.groupby('cluster')[[
    'Tenure Months',
    'Monthly Charges',
    'Total Charges',
    'Churn Probability'
]].mean()

# %%
clusters_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# cluster
# 0            11.118738        73.754082     904.016234           0.686490
# 1            58.807059        90.628588    5332.039529           0.227215
# 2            32.067416        33.397978    1083.450899           0.134227

# %%
clusters_summary={
    0:'Budget Loyal Customer',
    1:'High Risk New Customer',
    2:'Loyal premium Customer'
}

# %%
segmentation_data['cluster segment']=segmentation_data['cluster'].map(clusters_summary)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Ensure 'scaled_data' is freshly created from 'segmentation_data' before clustering.
# 'segmentation_data' is assumed to be defined by previous cells (specifically '91bceDkm9oqN').
scaler = StandardScaler()
# Scale only the numerical columns relevant for clustering
scaled_data = scaler.fit_transform(segmentation_data[['Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Probability']])

# Perform K-Means clustering with 3 clusters, consistent with the later clusters_summary definition
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(scaled_data)
segmentation_data['cluster'] = clusters

# Define cluster summaries and map to create 'cluster segment'
clusters_summary = {
    0: 'Budget Loyal Customer',
    1: 'High Risk New Customer',
    2: 'Loyal premium Customer'
}
segmentation_data['cluster segment'] = segmentation_data['cluster'].map(clusters_summary)

plt.figure(figsize=(8,5))
sns.countplot(
    x='cluster segment',
    data=segmentation_data,
    palette='viridis'
)
plt.title('Customer Risk Segmentation')
plt.xlabel('Customer Segment')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 185              15            85.90        1269.55           0.716452
# 2715             18            56.80        1074.65           0.328659
# 3825              2            20.00          40.90           0.227716
# 1807              6            84.20         519.15           0.824308
# 132              40           104.80        4131.95           0.484764
# ...             ...              ...            ...                ...
# 6366             66           104.90        6891.45           0.120654
# 315              19            86.00        1532.45           0.711268
# 2439              2            90.35         190.50           0.709340
# 5002             68           110.20        7467.50           0.066674
# 1161             30            99.70        2967.35           0.779169
#
#       cluster         cluster segment  Cluster
# 185         0   Budget Loyal Customer        0
# ...

# %%
plt.figure(figsize=(10,8))

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Tenure Months',y='Monthly Charges', hue='cluster segment',data=segmentation_data, palette='viridis')
plt.title('Customer Segments by Tenure Months and Monthly Charges')
plt.xlabel('Tenure Months')
plt.ylabel('Monthly Charges')
plt.legend(title='Customer Segment')
plt.grid(True)
plt.show()

# %%
segmentation_data.groupby('cluster')[
    ['Tenure Months',
     'Monthly Charges',
     'Total Charges',
     'Churn Probability']
].mean()
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# cluster
# 0            11.055556        73.605556     897.122963           0.685197
# 1            58.760563        90.658685    5328.899648           0.228435
# 2            32.176072        33.329797    1085.687472           0.133172

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Tenure Months', y='Monthly Charges',
                hue='cluster segment', data=segmentation_data,
                palette='Spectral', s=50, alpha=0.7)

plt.title('Customer Segments by Tenure Months and Monthly Charges', fontsize=14, fontweight='bold')
plt.xlabel('Tenure Months', fontsize=12)
plt.ylabel('Monthly Charges', fontsize=12)

# Ye line change ki hai - legend bahar aa jayega
plt.legend(title='Customer Segment', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout() # Ye zaroori hai warna legend cut ho jayega
plt.show()
